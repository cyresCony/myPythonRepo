# %%
import pandas as pd

incomeStatementRaw = {"1928-12-31":{
  "Sales": 294778287,
  "Deduct-Manufaturing cost, administrative, selling and general expense and taxes": 253848844,
  "Provision for depleption, depreciation and obsolence": 13658355,
  "Operating Income": 27271108,
  "Add-interest, dividents and other miscellaneous income": 2591693,
  "Total Income": 29862801,
  "Deduct-Interest charges": 11276879,
  "Net Income": 18585922,
  "Deduct-Dividents on Preferred Stock": 6842500,
  "Net for Common Stock": 11743422,
  "Deduct-Dividents on Common Stock": 1800000,
  "Transfered to Surplus": 9943422
}}

# %%
incStm = pd.DataFrame.from_dict(incomeStatementRaw, orient = 'index')
incStm = incStm.T
#incStm

# %%
balanceSheetRaw = {"1928-12-31":{
  "Cash": 28470936,
  "U.S. Government securities": 27247838,
  "Sundry marketable securities": 1980000,
  "Preferred stock held for employees less payments on account": 7742698,
  "Accounts and notes receivable": 41951684,
  "Inventories": 61539137,
  "Total Current Assets": 168932293,
  "Reserve Fund Assets": 6917227,
  "Sundry securities, and real estate installment contracts and mortgages": 3837820,
  "Funds in hands of Trustees": 691311,
  "Investments in and advances to affiliated companies": 8654700,
  "Property account": 654731533,
  "Less reserve for depreciation and depletion": 200408672,
  "Property account (net)": 454322855,
  "Accounts payable and accrued liabilities": 25227323,
  "Bond interest accrued": 2998122,
  "Preferred stock divident payable January 2, and April 1, 1929":2447500,
  "Common stock dividend payable May 15, 1929": 1800000,
  "Total Current Liabilities": 33472945,
  "Funded debt": 199421172,
  "Cambria Iron Company stock (annual rental of 4% payable)": 8465625,
  "7% Cumulative Pfd. Stock, $100 par value": 100000000,
  "Common Stock, $100 par value": 180000000,
  "Surplus": 114922652,
  "Contingent reserve": 2138990,
  "Insurance reserves": 4934822
}}

# %%
balSh = pd.DataFrame.from_dict(balanceSheetRaw, orient = 'index')
balSh = balSh.T
#balSh

# %%
incStm
# Out:
#                                                     1928-12-31
# Sales                                                294778287
# Deduct-Manufaturing cost, administrative, selli...   253848844
# Provision for depleption, depreciation and obso...    13658355
# Operating Income                                      27271108
# Add-interest, dividents and other miscellaneous...     2591693
# Total Income                                          29862801
# Deduct-Interest charges                               11276879
# Net Income                                            18585922
# Deduct-Dividents on Preferred Stock                    6842500
# Net for Common Stock                                  11743422
# Deduct-Dividents on Common Stock                       1800000
# Transfered to Surplus                                  9943422

# %%
balSh
# Out:
#                                                     1928-12-31
# Cash                                                  28470936
# U.S. Government securities                            27247838
# Sundry marketable securities                           1980000
# Preferred stock held for employees less payment...     7742698
# Accounts and notes receivable                         41951684
# Inventories                                           61539137
# Total Current Assets                                 168932293
# Reserve Fund Assets                                    6917227
# Sundry securities, and real estate installment ...     3837820
# Funds in hands of Trustees                              691311
# Investments in and advances to affiliated compa...     8654700
# Property account                                     654731533
# Less reserve for depreciation and depletion          200408672
# Property account (net)                               454322855
# ...
